# %%
from pandas import read_excel
from requests import get
from bs4 import BeautifulSoup

# %%
df = read_excel("Output Data Structure.xlsx")

# %%
list_specific_tag_not_found = []

for i in df["URL"] :
    r = get(i)
    if "td-post-content tagdiv-type" not in r.content.__str__() :
        list_specific_tag_not_found.append(i)

# %%
list_specific_tag_not_found
# Out:
# ['https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/',
#  'https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/',
#  'https://insights.blackcoffer.com/ensuring-growth-through-insurance-technology/']

# %%
df
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0               NaN             NaN             NaN                 NaN
# ...

# %%
lst_title = []
lst_exceptions_article = []

def make_write_file(file_title : str , file_content : str | None) :
    with open(file_title,'w',encoding='utf-16') as file :
        file.write(file_content)

for x in range(df.__len__()) :
    
    i = df.loc[x,"URL"]
    j = df.loc[x,"URL_ID"]
    try :
        r = get(i)

        soup = BeautifulSoup(r.content , "html.parser")

        z = soup.find("div",class_="td-post-content tagdiv-type")
        if type(z) == type(None) :
            z = soup.find("div",class_="tdb-block-inner td-fix-index")
            if type(z) == type(None) :
                lst_title.append(None)
                make_write_file(str(j)+".txt" , None)
                continue

        lst_title.append(soup.title.text)
        make_write_file(str(j)+".txt" , z.text)
    except UnicodeEncodeError :
        lst_exceptions_article.append("Unicode Error at URL ID : "+str(j))
    except Exception as e :
        lst_exceptions_article.append("Exception at URL ID: "+str(j))

# %%
lst_exceptions_article
# Out:
# []

# %%
df["Title"] = lst_title

# %%
df.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...             NaN
# 1      38  https://insights.blackcoffer.com/what-if-the-c...             NaN
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...             NaN
# 3      40  https://insights.blackcoffer.com/will-machine-...             NaN
# 4      41  https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
# ...

# %%
df.to_excel("Output Data Structure.xlsx",index= False)
