# %%
from pandas import read_excel
from Analyzer import *

# %%
df = read_excel("Input.xlsx")

# %%
df.head()
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...

# %%
lst_data = []
for i in df["URL_ID"] :
    lst_data.append(Analyze_File("./articles/"+str(i)+".txt"))

# %%
lst_data.__len__() == df.__len__()
# Out:
# True

# %%
temp = lst_data[0]

# %%
for i in lst_data[0].keys() :
    lst = []
    for j in lst_data : lst.append(j[i])
    df[i] = lst

# %%
df.head()
# Out:
#    URL_ID                                                URL  Positive Score  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...               0
# 1      38  https://insights.blackcoffer.com/what-if-the-c...               0
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...               0
# 3      40  https://insights.blackcoffer.com/will-machine-...               0
# 4      41  https://insights.blackcoffer.com/will-ai-repla...               0
#
#    Negative Score  Polarity Score  Subjectivity Score Average sentence length  \
# 0               0             0.0                 0.0                 1 words
# 1               0             0.0                 0.0            83.122 words
# 2               0             0.0                 0.0           109.452 words
# 3               0             0.0                 0.0            82.979 words
# 4               0             0.0                 0.0           100.782 words
#
# ...

# %%
df.tail()
# Out:
#      URL_ID                                                URL  \
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      Positive Score  Negative Score  Polarity Score  Subjectivity Score  \
# 109               0               0             0.0                 0.0
# 110               0               0             0.0                 0.0
# 111               0               0             0.0                 0.0
# 112               0               0             0.0                 0.0
# 113               0               0             0.0                 0.0
#
#     Average sentence length Number of Complex Words  \
# 109            90.185 words                 0 words
# ...

# %%
df.to_excel("Output_File.xlsx",index= False)
